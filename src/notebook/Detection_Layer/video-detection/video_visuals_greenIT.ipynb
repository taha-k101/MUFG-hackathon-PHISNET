# %% [markdown]
# # **Green IT Video **

# %%
# Assume 1 energy unit ~ 0.0005 kg CO2 (example scaling)
co2_per_epoch = 0.0005
co2_saved = co2_per_epoch * (len(clf.history['loss']) - clf.best_epoch)

plt.figure(figsize=(6,4))
plt.bar(['CO2 Saved (kg)'], [co2_saved], color='forestgreen')
plt.title("Estimated Carbon Footprint Reduction via Early Stopping (Green IT)")
plt.show()

# %%
co2_per_epoch = 0.0005
co2_dynamic = np.array([co2_per_epoch*epoch for epoch in range(1,len(epochs)+1)])

plt.figure(figsize=(8,5))
plt.plot(epochs, co2_dynamic, color='green', marker='x', linestyle='--')
plt.fill_between(epochs, co2_dynamic, color='green', alpha=0.2)
plt.title("CO2 Emission Reduction Across Epochs (Green IT)")
plt.xlabel("Epoch")
plt.ylabel("CO2 Saved (kg)")
plt.grid(True)
plt.show()

# %%
from math import pi

metrics = ['Accuracy','Loss','Energy Proxy']
values_video = [0.68, 0.32, 13]   # dummy scaled values
values_audio = [0.64, 0.36, 15]
values_fusion = [0.73, 0.27, 12]

values_video += values_video[:1]
values_audio += values_audio[:1]
values_fusion += values_fusion[:1]

angles = [n / float(len(metrics)) * 2 * pi for n in range(len(metrics))]
angles += angles[:1]

fig = plt.figure(figsize=(7,7))
ax = plt.subplot(111, polar=True)

ax.plot(angles, values_video, color='blue', linewidth=2, label='Video')
ax.fill(angles, values_video, color='blue', alpha=0.25)

ax.plot(angles, values_audio, color='red', linewidth=2, label='Audio')
ax.fill(angles, values_audio, color='red', alpha=0.25)

ax.plot(angles, values_fusion, color='green', linewidth=2, label='Fusion')
ax.fill(angles, values_fusion, color='green', alpha=0.25)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(metrics)
plt.title("Multi-Modality Comparison (Agentic & Reinforced Detection)")
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(cumulative_energy, loss_values, c=epochs, cmap='viridis', s=50)
plt.colorbar(label='Epoch')
plt.xlabel('Cumulative Energy (units)')
plt.ylabel('Loss')
plt.title('Energy Efficiency per Epoch (Green IT)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(epochs, co2_dynamic, color='green', marker='x', linestyle='--', label='Cumulative CO2 Saved')
plt.fill_between(epochs, co2_dynamic, color='green', alpha=0.2)
plt.xlabel('Epoch')
plt.ylabel('CO2 Saved (kg)')
plt.title('Dynamic Carbon Footprint Reduction (Green IT)')
plt.grid(True)
plt.legend()
plt.show()

# %%
efficiency_ratio = np.array([loss_values[0]-l for l in loss_values]) / cumulative_energy

plt.figure(figsize=(8,5))
plt.plot(epochs, efficiency_ratio, marker='o', color='purple')
plt.title("Epoch Efficiency Ratio (Loss Reduction per Energy Unit)")
plt.xlabel("Epoch")
plt.ylabel("Efficiency Ratio")
plt.grid(True)
plt.show()

# %%
modalities = ['Video', 'Audio', 'Fusion']
energy_scores = [cumulative_energy[-1], cumulative_energy[-1]*1.1, cumulative_energy[-1]*0.9]  # example

plt.figure(figsize=(7,5))
sns.barplot(x=modalities, y=energy_scores, palette='Greens')
plt.title("Energy Consumption per Detection Modality (Green IT)")
plt.ylabel("Cumulative Energy Units")
plt.show()
# Out:
# /tmp/ipython-input-2094172081.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=modalities, y=energy_scores, palette='Greens')
